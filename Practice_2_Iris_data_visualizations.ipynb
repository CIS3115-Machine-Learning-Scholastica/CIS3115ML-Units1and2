# %% [markdown]
# # Practice 2: Analysis and Visualization of Iris data
#
# Use this notebook as the starting point for Practice 2 activities.
#
# Student Name: ___________

# %% [markdown]
# ## The Iris classification problem
#
# *Note: This description comes from [Google's Custom Training Walkthroughs](https://www.tensorflow.org/tutorials/eager/custom_training_walkthrough).*
#
# Imagine you are a botanist seeking an automated way to categorize each Iris flower you find. Machine learning provides many algorithms to classify flowers statistically. For instance, a sophisticated machine learning program could classify flowers based on photographs. Our ambitions are more modest—we're going to classify Iris flowers based on the length and width measurements of their [sepals](https://en.wikipedia.org/wiki/Sepal) and [petals](https://en.wikipedia.org/wiki/Petal).
#
# The Iris genus entails about 300 species, but our program will only classify the following three:
#
# * Iris setosa
# * Iris virginica
# * Iris versicolor
#
# <table>
#   <tr><td>
#     <img src="https://www.tensorflow.org/images/iris_three_species.jpg"
#          alt="Petal geometry compared for three iris species: Iris setosa, Iris virginica, and Iris versicolor">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1.</b> <a href="https://commons.wikimedia.org/w/index.php?curid=170298">Iris setosa</a> (by <a href="https://commons.wikimedia.org/wiki/User:Radomil">Radomil</a>, CC BY-SA 3.0), <a href="https://commons.wikimedia.org/w/index.php?curid=248095">Iris versicolor</a>, (by <a href="https://commons.wikimedia.org/wiki/User:Dlanglois">Dlanglois</a>, CC BY-SA 3.0), and <a href="https://www.flickr.com/photos/33397993@N05/3352169862">Iris virginica</a> (by <a href="https://www.flickr.com/photos/33397993@N05">Frank Mayfield</a>, CC BY-SA 2.0).<br/>&nbsp;
#   </td></tr>
# </table>
#
# Fortunately, someone has already created a [data set of 120 Iris flowers](https://en.wikipedia.org/wiki/Iris_flower_data_set) with the sepal and petal measurements. This is a classic dataset that is popular for beginner machine learning classification problems.

# %% [markdown]
# ## Setting up Python tools
#
# *The following section is taken from a well-known example of [data analysis of the Iris data by Ben Hammer](https://www.kaggle.com/benhamner/python-data-visualizations/data), chief technology officer of data science firm Kaggle*
#
# We'll use three libraries for this tutorial: [pandas](http://pandas.pydata.org/), [matplotlib](http://matplotlib.org/), and [seaborn](http://stanford.edu/~mwaskom/software/seaborn/).

# %%
# First, we'll import pandas, a data processing and CSV file I/O library
import pandas as pd

# We'll also import seaborn and matplot, twp Python graphing libraries
import seaborn as sns
import matplotlib.pyplot as plt
#sns.set(style="white", color_codes=True)

# We will turn off some warns in this notebook to make it easier to read for new students
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read in the Iris flower data
# The Iris flower data is read in from a file stored on the internet
# <p>
# It is stored in a Pandas DataFrame which is similar to an internal spreadsheet in that the data is stored in rows and columns.

# %%
# Read in the data file from stored in a raw file in GitHub
url = 'https://raw.githubusercontent.com/CIS3115-Machine-Learning-Scholastica/CIS3115ML-Units1and2/master/Iris_mod.csv'
iris = pd.read_csv(url)
# Set the Id column as the index since it is unique for each flower
iris.set_index('Id', inplace=True)

# %%
# Display the first 5 rows at the start, or head, of the dataframe
iris.head(5)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Try different code samples here. See the Task below for details
#iris.head(10)
iris.head
#iris
#print (iris)
#iris.tail(5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# 6              5.4           3.9            1.7           0.4     Iris-setosa
# 7              4.6           3.4            1.4           0.3     Iris-setosa
# 8              5.0           3.4            1.5           0.2     Iris-setosa
# 9              4.4           2.9            1.4           0.2     Iris-setosa
# 10             4.9           3.1            1.5           0.1     Iris-setosa
# 11             5.4           3.7            1.5           0.2     Iris-setosa
# ...

# %% [markdown]
# ## Task 1: Describe different ways to display the data
# In the code cell above, try some different commands to display the Iris data and compare it with the `iris.head(5)`command done above.
# </P>
# You can simply delete the '#' from each line in turn to un-comment it and make it run
# - iris.head(10)
# - iris.head
# - iris
# - print (iris)
# - iris.tail(5)
#
# </P>
# Describe at the results of at least 3 different commands here:
#
# ---
# *Double-click on this cell to put your answer here...*

# %%
iris.SepalWidthCm
#iris['SepalWidthCm']
#iris.iloc[ 20:25 , 2:4 ]
#iris.iloc[ : , 2:4]
#iris.iloc[ 20:25 ]
# Out:
# Id
# 1       3.5
# 2       3.0
# 3       3.2
# 4       3.1
# 5       3.6
# 6       3.9
# 7       3.4
# 8       3.4
# 9       2.9
# 10      3.1
# 11      3.7
# 12      3.4
# 13     30.0
# 14      3.0
# 15      4.0
# 16      4.4
# 17      3.9
# 18      3.5
# 19      3.8
# 20      3.8
# 21      3.4
# 22      3.7
# 23      3.6
# 24      3.3
# 25      3.4
# 26      3.0
# 27      3.4
# 28      3.5
# 29      3.4
# 30      3.2
#        ...
# 121     3.2
# 122     2.8
# 123     2.8
# 124     2.7
# 125     3.3
# 126     3.2
# 127     2.8
# 128     3.0
# 129     2.8
# 130     3.0
# 131     2.8
# 132     3.8
# 133     2.8
# 134     2.8
# 135     2.6
# 136     3.0
# 137     3.4
# 138     3.1
# 139     3.0
# 140     3.1
# 141     3.1
# 142     3.1
# 143     2.7
# 144     3.2
# 145     3.3
# 146     3.0
# 147     2.5
# 148     3.0
# 149     3.4
# 150     3.0
# Name: SepalWidthCm, Length: 151, dtype: float64

# %% [markdown]
# ## Task 2: Select a column or row
# In the code cell above, try some different commands to select one or more rows or columns.
# </P>
# You can simply delete the '#' from each line in turn to un-comment it and make it run
# - iris.SepalWidthCm
# - iris['SepalWidthCm']
# - iris.iloc[ 20:25 , 2:4 ]
# - iris.iloc[ : , 2:4]
# - iris.iloc[ 20:25 ]
#
# </P>
# Describe at the results of at least 3 different commands here:
#
# ---
# *Double-click on this cell to put your answer here...*

# %% [markdown]
# ### Investigating the data and looking for anomalies
#
# **Why not spreadsheets or a SQL database?**
# Small data sets like the Iris flower data can actually be openned up as a spreadsheet or an SQL database. Here is the [Iris data as a Google Spreadsheet](https://docs.google.com/spreadsheets/d/1CtyNtFq5y31sp1XZwZVe8KAba0g2Uh7NZdAXyQbU5vw/edit?usp=sharing).
# <\P>
# But most data in machine learning is too large to view in a spreadsheet or open as a database. For example, a movie rating data file might have 10,000,000 movies each tagged with 2,500 different text tags. For large files like this, we must use data analysis tools like Python.

# %%
print ("This is the shape of the iris data, the number of rows and columns: " , iris.shape)
# Out:
# This is the shape of the iris data, the number of rows and columns:  (151, 5)

# %%
print ("This is a count of the number of item in each column: ", iris.count())
print ("NOTE: notice that two columns only have 150 values so one of their values must be null")
# Out:
# This is a count of the number of item in each column:  SepalLengthCm    151
# SepalWidthCm     151
# PetalLengthCm    150
# PetalWidthCm     150
# Species          151
# dtype: int64
# NOTE: notice that two columns only have 150 values so one of their values must be null

# %%
print ("This is the overall information about the data")

iris.info()
# Out:
# This is the overall information about the data
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 1 to 150
# Data columns (total 5 columns):
# SepalLengthCm    151 non-null float64
# SepalWidthCm     151 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          151 non-null object
# dtypes: float64(4), object(1)
# memory usage: 12.1+ KB

# %%
# Let's see how many examples we have of each species
iris["Species"].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Missing Data        1
# Name: Species, dtype: int64

# %% [markdown]
# ### Remove null or empty values.
#
# Since at least one row seems to have null or empty values, we can use `dropna() `to remove any rows with empty values. "dropna" is short for "drop not-a-number"
# </p>
# We will save the iris data into a new dataframe named **iris_clean.** From now on, we will use this rather than the orifinal iris datafram

# %%
iris_clean = iris.dropna()

# %%
# info now shows that there are 150 non-null values in each column, which is good
iris_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %% [markdown]
# ## Task 3: Remove null values
# In your own words, describe what the following code does
#
# ```
# iris_clean = iris.dropna()
# ```
#
# Also, what do you think the following code would do?
#
# ```
# iris = iris.dropna()
# ```
#
# </P>
#
#
# ---
# *Double-click on this cell to put your answer here...*

# %% [markdown]
# ### Find and remove abnormal or erroneous data
# Sometimes there will be errors in the data or abnormal data that is a result of errors in data input or processing. We will try a few things
# - Look at the 10 largest values on different collumns to see if any standout as errors
# - Look at the 10 smallest values to look for any values that look like errors
# - Plot the data to see if any values look strange

# %%
# display the flowers with the 10 largest sepal lenghts
iris_clean.nlargest(10, 'SepalLengthCm')
# NOTE Flower with ID of 13 has some values that are very large. These are error values and should be removed
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 13            48.0          30.0           14.0           1.0     Iris-setosa
# 132            7.9           3.8            6.4           2.0  Iris-virginica
# 118            7.7           3.8            6.7           2.2  Iris-virginica
# 119            7.7           2.6            6.9           2.3  Iris-virginica
# 123            7.7           2.8            6.7           2.0  Iris-virginica
# 136            7.7           3.0            6.1           2.3  Iris-virginica
# 106            7.6           3.0            6.6           2.1  Iris-virginica
# 131            7.4           2.8            6.1           1.9  Iris-virginica
# 108            7.3           2.9            6.3           1.8  Iris-virginica
# 110            7.2           3.6            6.1           2.5  Iris-virginica

# %%
# display the flowers with the 10 smallest petal widths
iris_clean.nsmallest(10, 'PetalWidthCm')
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 10            4.9           3.1            1.5           0.1  Iris-setosa
# 14            4.3           3.0            1.1           0.1  Iris-setosa
# 33            5.2           4.1            1.5           0.1  Iris-setosa
# 35            4.9           3.1            1.5           0.1  Iris-setosa
# 38            4.9           3.1            1.5           0.1  Iris-setosa
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Display a simple plot of the data to look for errors or adnormal values
iris_clean.plot()

# %% [markdown]
# ## Bonus Challenge: using boxplots and standard deviations on outliers
#
# This section looks at some better tools to identifying outliers. It explains what a standard deviation is and how it can be used.
#
# *If you find this section confusing, you can skip to the next task below.*
#
# Start by watching [Standard Deviation - 60 Second Data Science ](https://www.youtube.com/watch?v=1EGtm3ClkIc)

# %% [markdown]
# ### the BoxPlot uses standard deviations to show the spread of the data
#
# The first plot of PetalLengthCm shows two clumps of data witn one really large outlier. This is a problem because the BoxPlot and standard deviation are designed for more normal data distributions.
#
# The second plot breaks PetalLengthCm up by species and the data is more normallly spread. We can still see the one large outlier is a Iris-setosa.
#
# For more info see[ Understanding the BoxPlot ](https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51)by Towards Data Science.

# %%
sns.swarmplot("PetalLengthCm", data=iris_clean)
sns.boxplot(x="PetalLengthCm", data=iris_clean, boxprops=dict(alpha=.3))

# %%
sns.boxplot("Species", "PetalLengthCm", data=iris_clean, boxprops=dict(alpha=.3))
sns.swarmplot("Species", "PetalLengthCm", data=iris_clean, zorder=.5)

# %% [markdown]
# ### Z-score
#
# The Z-score measures the number of standard deviations away from the average. In general 95% off the points are within two standard deviations and 99.7% are withing three standard deviations--see the [68-95-99.7 rule](https://en.wikipedia.org/wiki/68%E2%80%9395%E2%80%9399.7_rule) for details.
#
# So data points with a Z-score above 3 are outliers. The code below stores the Z-code for each value of SepalWidthCm in a new variable named SepalWidth_Z. Note that most of the Z values are less than 1.0 , but one is over 11--this is our outlier.
#
# We can then print out the corresponding rows to display the outliers in the second cell.

# %%
from scipy import stats
import numpy as np
SepalWidth_Z = np.abs(stats.zscore(iris_clean['SepalWidthCm']))
print (SepalWidth_Z)
# Out:
# [ 0.1190194   0.10470128  0.01521301  0.05995714  0.16376354  0.29799595
#   0.07427527  0.07427527  0.14944542  0.05995714  0.20850768  0.07427527
#  11.97621574  0.10470128  0.34274009  0.52171664  0.29799595  0.1190194
#   0.25325182  0.25325182  0.07427527  0.20850768  0.16376354  0.02953113
#   0.07427527  0.10470128  0.07427527  0.1190194   0.07427527  0.01521301
#   0.05995714  0.07427527  0.38748423  0.43222836  0.05995714  0.01521301
#   0.1190194   0.05995714  0.10470128  0.07427527  0.1190194   0.41791024
#   0.01521301  0.1190194   0.25325182  0.10470128  0.25325182  0.01521301
#   0.20850768  0.02953113  0.01521301  0.01521301  0.05995714  0.41791024
#   0.19418956  0.19418956  0.02953113  0.3731661   0.14944542  0.23893369
#   0.55214265  0.10470128  0.46265438  0.14944542  0.14944542  0.05995714
#   0.10470128  0.23893369  0.46265438  0.32842197  0.01521301  0.19418956
#   0.32842197  0.19418956  0.14944542  0.10470128  0.19418956  0.10470128
# ...

# %%
iris_clean[(SepalWidth_Z > 3)]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 13           48.0          30.0           14.0           1.0  Iris-setosa

# %% [markdown]
# For more details, you can see [Ways to Detect and Remove the Outliers ](https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba)from Towards Data Science.

# %% [markdown]
#  ## Task 4: Remove rows with eorroneous values
# After analyzing the data above, remove any rows with erroneous values
#
# The following command removes all rows with a Sepal Length of 30.
#
# ```
# iris_clean = iris_clean[ iris_clean.SepalLengthCm != 30 ]
# ```
#
# You can also delete a row be number. The following code removes row number 8 from the data frame
#
# ```
# iris_clean = iris_clean.drop(iris_clean.index[8])
# ```
#
#
# ---
# ### Enter the code in the cell below to remove any bad rows from the data.
# The plot cell that follows should not show any abnormal values

# %%
# Enter your code here to remove any adnormal rows

# %%
# Plot the data again to see if the erroreous values have been removed
iris_clean.plot()

# %% [markdown]
# ## Task 5: Modifying the visualizations
# For each of the following seven visualizations, make at least one change to the parameters to change the graphs. Possibilities include:
# - Changing the columns between SepalLengthCm,	SepalWidthCm,	PetalLengthCm, and PetalWidthCm
# - Changing parameters such as `size=5`

# %%
# First replace the original iris data with the new cleaned up version
iris = iris_clean

# %%
# The first way we can plot things is using the .plot extension from Pandas dataframes
# We'll use this to make a scatterplot of the Iris features.
iris.plot(kind="scatter", x="SepalLengthCm", y="SepalWidthCm")

# %%
# We can also use the seaborn library to make a similar plot
# A seaborn jointplot shows bivariate scatterplots and univariate histograms in the same figure
sns.jointplot(x="SepalLengthCm", y="SepalWidthCm", data=iris, size=5)

# %%
# One piece of information missing in the plots above is what species each plant is
# We'll use seaborn's FacetGrid to color the scatterplot by species
sns.FacetGrid(iris, hue="Species", size=5) \
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
   .add_legend()

# %%
# We can look at an individual feature in Seaborn through a boxplot
sns.boxplot(x="Species", y="PetalLengthCm", data=iris)

# %%
# One way we can extend this plot is adding a layer of individual points on top of
# it through Seaborn's striplot
# 
# We'll use jitter=True so that all the points don't fall in single vertical lines
# above the species
#
# Saving the resulting axes as ax each time causes the resulting plot to be shown
# on top of the previous axes
ax = sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
ax = sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")

# %%
# A violin plot combines the benefits of the previous two plots and simplifies them
# Denser regions of the data are fatter, and sparser thiner in a violin plot
sns.violinplot(x="Species", y="PetalLengthCm", data=iris, size=6)

# %%
# A final seaborn plot useful for looking at univariate relations is the kdeplot,
# which creates and visualizes a kernel density estimate of the underlying feature
sns.FacetGrid(iris, hue="Species", size=6) \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()

# %% [markdown]
# ## Task 6: Describe following graphe
# In your own words, describe what the following two multi-part graph displays
#
#
# </P>
#
#
# ---
# *Double-click on this cell to put your answer here...*

# %%
# Another useful seaborn plot is the pairplot, which shows the bivariate relation
# between each pair of features
# 
# From the pairplot, we'll see that the Iris-setosa species is separataed from the other
# two across all feature combinations
sns.pairplot(iris.drop("Id", axis=1), hue="Species", size=3)

# %%
# The diagonal elements in a pairplot show the histogram by default
# We can update these elements to show other things, such as a kde
sns.pairplot(iris.drop("Id", axis=1), hue="Species", size=3, diag_kind="kde")

# %% [markdown]
# ## Task 7: Find a new visualization
# Find another example of a visualization of the iris data and insert it in the code block below.
#
# </P>
# While you can search the internet for something like "Iris data visualization in Python" one specific good place to look is[ Seaborn plot to visualize Iris data](https://www.kaggle.com/biphili/seaborn-plot-to-visualize-iris-data) from Kaggle

# %%
# Add code here for some new visualization of the Iris data

# %% [markdown]
# ## Wrapping Up
#
# Remember to share this sheet with your instructor and submit a link to it in Blackboard.
